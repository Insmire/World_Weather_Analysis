# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
import requests
# Import the API key.
from config import weather_api_key
import time

# %%
# Create a set of 2,000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 731

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description=city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description
                         })
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | isangel
# Processing Record 2 of Set 1 | iqaluit
# Processing Record 3 of Set 1 | ambilobe
# Processing Record 4 of Set 1 | acapulco
# Processing Record 5 of Set 1 | krasnoznamensk
# Processing Record 6 of Set 1 | jumla
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | kandi
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | novoagansk
# Processing Record 13 of Set 1 | hithadhoo
# Processing Record 14 of Set 1 | nioro
# Processing Record 15 of Set 1 | kichera
# Processing Record 16 of Set 1 | christchurch
# Processing Record 17 of Set 1 | opuwo
# Processing Record 18 of Set 1 | sinnamary
# Processing Record 19 of Set 1 | hasaki
# Processing Record 20 of Set 1 | margate
# Processing Record 21 of Set 1 | port elizabeth
# Processing Record 22 of Set 1 | esperance
# Processing Record 23 of Set 1 | kosjeric
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | torbay
# Processing Record 26 of Set 1 | puerto ayora
# Processing Record 27 of Set 1 | oussouye
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | hirara
# Processing Record 30 of Set 1 | novobirilyussy
# Processing Record 31 of Set 1 | flin flon
# Processing Record 32 of Set 1 | mar del plata
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | aykhal
# Processing Record 36 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 1 | kruisfontein
# Processing Record 38 of Set 1 | qui nhon
# Processing Record 39 of Set 1 | nikolskoye
# Processing Record 40 of Set 1 | gravdal
# Processing Record 41 of Set 1 | tuatapere
# Processing Record 42 of Set 1 | bengkulu
# Processing Record 43 of Set 1 | bluff
# Processing Record 44 of Set 1 | vaini
# Processing Record 45 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 1 | ogembo
# Processing Record 47 of Set 1 | kodiak
# Processing Record 48 of Set 1 | saint-philippe
# Processing Record 49 of Set 1 | faanui
# Processing Record 50 of Set 1 | mahebourg
# Processing Record 1 of Set 2 | estepa
# Processing Record 2 of Set 2 | daru
# Processing Record 3 of Set 2 | avarua
# Processing Record 4 of Set 2 | novyy urengoy
# Processing Record 5 of Set 2 | thompson
# Processing Record 6 of Set 2 | golden
# Processing Record 7 of Set 2 | hobart
# Processing Record 8 of Set 2 | bredasdorp
# Processing Record 9 of Set 2 | kavieng
# Processing Record 10 of Set 2 | portland
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | sandovo
# Processing Record 13 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 2 | were ilu
# Processing Record 15 of Set 2 | upernavik
# Processing Record 16 of Set 2 | nanortalik
# Processing Record 17 of Set 2 | pisco
# Processing Record 18 of Set 2 | tiksi
# Processing Record 19 of Set 2 | san quintin
# Processing Record 20 of Set 2 | te anau
# Processing Record 21 of Set 2 | hervey bay
# Processing Record 22 of Set 2 | castro
# Processing Record 23 of Set 2 | zhezkazgan
# Processing Record 24 of Set 2 | port blair
# Processing Record 25 of Set 2 | bethel
# Processing Record 26 of Set 2 | faya
# Processing Record 27 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 2 | xining
# Processing Record 29 of Set 2 | zhangye
# Processing Record 30 of Set 2 | talnakh
# Processing Record 31 of Set 2 | shahpura
# Processing Record 32 of Set 2 | constitucion
# Processing Record 33 of Set 2 | biak
# Processing Record 34 of Set 2 | chokurdakh
# Processing Record 35 of Set 2 | henties bay
# Processing Record 36 of Set 2 | quelimane
# Processing Record 37 of Set 2 | east london
# Processing Record 38 of Set 2 | catalina
# Processing Record 39 of Set 2 | bambous virieux
# Processing Record 40 of Set 2 | severo-kurilsk
# Processing Record 41 of Set 2 | atuona
# Processing Record 42 of Set 2 | sibenik
# Processing Record 43 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 2 | namatanai
# Processing Record 45 of Set 2 | mayo
# Processing Record 46 of Set 2 | taicheng
# Processing Record 47 of Set 2 | coquimbo
# Processing Record 48 of Set 2 | penarroya-pueblonuevo
# Processing Record 49 of Set 2 | chitrakonda
# Processing Record 50 of Set 2 | smithers
# Processing Record 1 of Set 3 | gimli
# Processing Record 2 of Set 3 | punta arenas
# Processing Record 3 of Set 3 | jamestown
# Processing Record 4 of Set 3 | saskylakh
# Processing Record 5 of Set 3 | saldanha
# Processing Record 6 of Set 3 | quatre cocos
# Processing Record 7 of Set 3 | nsanje
# Processing Record 8 of Set 3 | gigmoto
# Processing Record 9 of Set 3 | karratha
# Processing Record 10 of Set 3 | santa isabel do rio negro
# Processing Record 11 of Set 3 | yablonovo
# Processing Record 12 of Set 3 | butaritari
# Processing Record 13 of Set 3 | swan river
# Processing Record 14 of Set 3 | kalmunai
# Processing Record 15 of Set 3 | hermanus
# Processing Record 16 of Set 3 | chuy
# Processing Record 17 of Set 3 | los llanos de aridane
# Processing Record 18 of Set 3 | sakata
# Processing Record 19 of Set 3 | manoel urbano
# Processing Record 20 of Set 3 | naze
# Processing Record 21 of Set 3 | ancud
# Processing Record 22 of Set 3 | kaspiysk
# Processing Record 23 of Set 3 | asau
# Processing Record 24 of Set 3 | bandarban
# Processing Record 25 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 26 of Set 3 | itaituba
# Processing Record 27 of Set 3 | husavik
# Processing Record 28 of Set 3 | rayadrug
# Processing Record 29 of Set 3 | kahului
# Processing Record 30 of Set 3 | hilo
# Processing Record 31 of Set 3 | ostrovnoy
# Processing Record 32 of Set 3 | san jose
# Processing Record 33 of Set 3 | collie
# Processing Record 34 of Set 3 | rawson
# Processing Record 35 of Set 3 | nagua
# Processing Record 36 of Set 3 | neryungri
# Processing Record 37 of Set 3 | majene
# Processing Record 38 of Set 3 | palmas bellas
# Processing Record 39 of Set 3 | nyurba
# Processing Record 40 of Set 3 | abu kamal
# Processing Record 41 of Set 3 | georgetown
# Processing Record 42 of Set 3 | katsuura
# Processing Record 43 of Set 3 | khatanga
# Processing Record 44 of Set 3 | lompoc
# Processing Record 45 of Set 3 | tecoanapa
# Processing Record 46 of Set 3 | karimpur
# Processing Record 47 of Set 3 | olafsvik
# Processing Record 48 of Set 3 | westport
# Processing Record 49 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 3 | oga
# Processing Record 1 of Set 4 | tasiilaq
# Processing Record 2 of Set 4 | ludvika
# Processing Record 3 of Set 4 | mayor pablo lagerenza
# Processing Record 4 of Set 4 | yaan
# Processing Record 5 of Set 4 | port hardy
# Processing Record 6 of Set 4 | ayna
# Processing Record 7 of Set 4 | masakin
# Processing Record 8 of Set 4 | batagay-alyta
# Processing Record 9 of Set 4 | kortkeros
# Processing Record 10 of Set 4 | pevek
# Processing Record 11 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 4 | dikson
# Processing Record 13 of Set 4 | cockburn town
# Processing Record 14 of Set 4 | san patricio
# Processing Record 15 of Set 4 | celestun
# Processing Record 16 of Set 4 | alice springs
# Processing Record 17 of Set 4 | bridgend
# Processing Record 18 of Set 4 | neftcala
# Processing Record 19 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 4 | loknya
# Processing Record 21 of Set 4 | camabatela
# Processing Record 22 of Set 4 | lebu
# Processing Record 23 of Set 4 | turka
# Processing Record 24 of Set 4 | buraydah
# Processing Record 25 of Set 4 | barrow
# Processing Record 26 of Set 4 | tevaitoa
# Processing Record 27 of Set 4 | belaya gora
# Processing Record 28 of Set 4 | dhidhdhoo
# Processing Record 29 of Set 4 | yulara
# Processing Record 30 of Set 4 | calama
# Processing Record 31 of Set 4 | nantucket
# Processing Record 32 of Set 4 | sfantu gheorghe
# Processing Record 33 of Set 4 | sitka
# Processing Record 34 of Set 4 | henderson
# Processing Record 35 of Set 4 | bacuit
# City not found. Skipping...
# Processing Record 36 of Set 4 | hamilton
# Processing Record 37 of Set 4 | yazman
# Processing Record 38 of Set 4 | playa vicente
# Processing Record 39 of Set 4 | skagastrond
# City not found. Skipping...
# Processing Record 40 of Set 4 | ayan
# Processing Record 41 of Set 4 | cabo san lucas
# Processing Record 42 of Set 4 | cidreira
# Processing Record 43 of Set 4 | atbasar
# Processing Record 44 of Set 4 | oxelosund
# Processing Record 45 of Set 4 | panaba
# Processing Record 46 of Set 4 | college
# Processing Record 47 of Set 4 | joshimath
# Processing Record 48 of Set 4 | charleston
# Processing Record 49 of Set 4 | qaanaaq
# Processing Record 50 of Set 4 | sarai
# Processing Record 1 of Set 5 | havre-saint-pierre
# Processing Record 2 of Set 5 | shubarshi
# Processing Record 3 of Set 5 | caxito
# Processing Record 4 of Set 5 | bahir dar
# Processing Record 5 of Set 5 | gambela
# Processing Record 6 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 5 | bintulu
# Processing Record 8 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 9 of Set 5 | marovoay
# Processing Record 10 of Set 5 | noumea
# Processing Record 11 of Set 5 | turayf
# Processing Record 12 of Set 5 | xam nua
# Processing Record 13 of Set 5 | ribeira grande
# Processing Record 14 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 5 | harindanga
# Processing Record 16 of Set 5 | nizwa
# Processing Record 17 of Set 5 | arlit
# Processing Record 18 of Set 5 | scottsburgh
# City not found. Skipping...
# Processing Record 19 of Set 5 | havelock
# Processing Record 20 of Set 5 | donskoye
# Processing Record 21 of Set 5 | sars
# Processing Record 22 of Set 5 | sayyan
# Processing Record 23 of Set 5 | flinders
# Processing Record 24 of Set 5 | lubango
# Processing Record 25 of Set 5 | saint anthony
# Processing Record 26 of Set 5 | kommunisticheskiy
# Processing Record 27 of Set 5 | leua
# Processing Record 28 of Set 5 | vila franca do campo
# Processing Record 29 of Set 5 | narrabri
# Processing Record 30 of Set 5 | kargasok
# Processing Record 31 of Set 5 | kaitangata
# Processing Record 32 of Set 5 | yellowknife
# Processing Record 33 of Set 5 | khandyga
# Processing Record 34 of Set 5 | fort nelson
# Processing Record 35 of Set 5 | kirksville
# Processing Record 36 of Set 5 | bozhou
# Processing Record 37 of Set 5 | trincomalee
# Processing Record 38 of Set 5 | scottsbluff
# Processing Record 39 of Set 5 | kapit
# Processing Record 40 of Set 5 | antofagasta
# Processing Record 41 of Set 5 | nabire
# Processing Record 42 of Set 5 | new norfolk
# Processing Record 43 of Set 5 | tuktoyaktuk
# Processing Record 44 of Set 5 | comodoro rivadavia
# Processing Record 45 of Set 5 | iskitim
# Processing Record 46 of Set 5 | alofi
# Processing Record 47 of Set 5 | nizhniy tsasuchey
# Processing Record 48 of Set 5 | ekhabi
# Processing Record 49 of Set 5 | sistranda
# Processing Record 50 of Set 5 | bassar
# Processing Record 1 of Set 6 | ayagoz
# Processing Record 2 of Set 6 | burica
# City not found. Skipping...
# Processing Record 3 of Set 6 | mujiayingzi
# Processing Record 4 of Set 6 | soro
# Processing Record 5 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 6 | tura
# Processing Record 7 of Set 6 | hofn
# Processing Record 8 of Set 6 | kon tum
# Processing Record 9 of Set 6 | maniitsoq
# Processing Record 10 of Set 6 | balykshi
# Processing Record 11 of Set 6 | emerald
# Processing Record 12 of Set 6 | saint-joseph
# Processing Record 13 of Set 6 | hami
# Processing Record 14 of Set 6 | half moon bay
# Processing Record 15 of Set 6 | ermelo
# Processing Record 16 of Set 6 | channel-port aux basques
# Processing Record 17 of Set 6 | zaragoza
# Processing Record 18 of Set 6 | lavrentiya
# Processing Record 19 of Set 6 | timbakion
# City not found. Skipping...
# Processing Record 20 of Set 6 | njombe
# Processing Record 21 of Set 6 | vestmannaeyjar
# Processing Record 22 of Set 6 | banmo
# City not found. Skipping...
# Processing Record 23 of Set 6 | norman wells
# Processing Record 24 of Set 6 | airai
# Processing Record 25 of Set 6 | nishihara
# Processing Record 26 of Set 6 | genhe
# Processing Record 27 of Set 6 | gizo
# Processing Record 28 of Set 6 | banda aceh
# Processing Record 29 of Set 6 | kozhva
# Processing Record 30 of Set 6 | kingman
# Processing Record 31 of Set 6 | kushiro
# Processing Record 32 of Set 6 | guane
# Processing Record 33 of Set 6 | carnarvon
# Processing Record 34 of Set 6 | mehamn
# Processing Record 35 of Set 6 | padang
# Processing Record 36 of Set 6 | wattegama
# Processing Record 37 of Set 6 | stekolnyy
# City not found. Skipping...
# Processing Record 38 of Set 6 | clyde river
# Processing Record 39 of Set 6 | vila velha
# Processing Record 40 of Set 6 | santa isabel
# Processing Record 41 of Set 6 | lypova dolyna
# Processing Record 42 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 43 of Set 6 | larsnes
# Processing Record 44 of Set 6 | ponta delgada
# Processing Record 45 of Set 6 | lebowakgomo
# Processing Record 46 of Set 6 | peleduy
# Processing Record 47 of Set 6 | boende
# Processing Record 48 of Set 6 | vagur
# Processing Record 49 of Set 6 | sept-iles
# Processing Record 50 of Set 6 | la palma
# Processing Record 1 of Set 7 | lazaro cardenas
# Processing Record 2 of Set 7 | camacha
# Processing Record 3 of Set 7 | itoman
# Processing Record 4 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 5 of Set 7 | qasigiannguit
# Processing Record 6 of Set 7 | codrington
# Processing Record 7 of Set 7 | lodja
# Processing Record 8 of Set 7 | malkara
# Processing Record 9 of Set 7 | tranas
# Processing Record 10 of Set 7 | agde
# Processing Record 11 of Set 7 | chaumont
# Processing Record 12 of Set 7 | zhigansk
# Processing Record 13 of Set 7 | mount isa
# Processing Record 14 of Set 7 | pangnirtung
# Processing Record 15 of Set 7 | kieta
# Processing Record 16 of Set 7 | lerwick
# Processing Record 17 of Set 7 | provideniya
# Processing Record 18 of Set 7 | leningradskiy
# Processing Record 19 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 20 of Set 7 | ilulissat
# Processing Record 21 of Set 7 | saint pete beach
# Processing Record 22 of Set 7 | phuket
# Processing Record 23 of Set 7 | sorong
# Processing Record 24 of Set 7 | arraial do cabo
# Processing Record 25 of Set 7 | salekhard
# Processing Record 26 of Set 7 | eyl
# Processing Record 27 of Set 7 | sinkat
# City not found. Skipping...
# Processing Record 28 of Set 7 | emba
# Processing Record 29 of Set 7 | sangar
# Processing Record 30 of Set 7 | ponta do sol
# Processing Record 31 of Set 7 | srednekolymsk
# Processing Record 32 of Set 7 | markova
# Processing Record 33 of Set 7 | gabu
# Processing Record 34 of Set 7 | monte gordo
# Processing Record 35 of Set 7 | ahipara
# Processing Record 36 of Set 7 | jibuti
# Processing Record 37 of Set 7 | tromso
# Processing Record 38 of Set 7 | asfi
# Processing Record 39 of Set 7 | mitchell
# Processing Record 40 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 7 | lasa
# Processing Record 42 of Set 7 | buta
# Processing Record 43 of Set 7 | bathsheba
# Processing Record 44 of Set 7 | vostok
# Processing Record 45 of Set 7 | cherskiy
# Processing Record 46 of Set 7 | susehri
# Processing Record 47 of Set 7 | vodnyy
# Processing Record 48 of Set 7 | cayenne
# Processing Record 49 of Set 7 | mandalgovi
# Processing Record 50 of Set 7 | huarmey
# Processing Record 1 of Set 8 | cihuatlan
# Processing Record 2 of Set 8 | ulaangom
# Processing Record 3 of Set 8 | vila do maio
# Processing Record 4 of Set 8 | strezhevoy
# Processing Record 5 of Set 8 | tual
# Processing Record 6 of Set 8 | vardo
# Processing Record 7 of Set 8 | roblin
# Processing Record 8 of Set 8 | polunochnoye
# Processing Record 9 of Set 8 | verkh-usugli
# Processing Record 10 of Set 8 | saint-jean-de-maurienne
# Processing Record 11 of Set 8 | grindavik
# Processing Record 12 of Set 8 | taoudenni
# Processing Record 13 of Set 8 | ponte de sor
# Processing Record 14 of Set 8 | oksovskiy
# Processing Record 15 of Set 8 | winsum
# Processing Record 16 of Set 8 | cordoba
# Processing Record 17 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 18 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 19 of Set 8 | vestbygda
# City not found. Skipping...
# Processing Record 20 of Set 8 | aklavik
# Processing Record 21 of Set 8 | sao felix do xingu
# Processing Record 22 of Set 8 | mocuba
# Processing Record 23 of Set 8 | saint george
# Processing Record 24 of Set 8 | lingao
# Processing Record 25 of Set 8 | muros
# Processing Record 26 of Set 8 | ierapetra
# Processing Record 27 of Set 8 | colombo
# Processing Record 28 of Set 8 | nardaran
# Processing Record 29 of Set 8 | harlingen
# Processing Record 30 of Set 8 | yerbogachen
# Processing Record 31 of Set 8 | maraa
# Processing Record 32 of Set 8 | omaruru
# Processing Record 33 of Set 8 | salinas
# Processing Record 34 of Set 8 | meredith
# Processing Record 35 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 8 | nouadhibou
# Processing Record 37 of Set 8 | mirnyy
# Processing Record 38 of Set 8 | zaysan
# Processing Record 39 of Set 8 | jujuy
# City not found. Skipping...
# Processing Record 40 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 8 | hukuntsi
# Processing Record 42 of Set 8 | kuching
# Processing Record 43 of Set 8 | doaba
# Processing Record 44 of Set 8 | bad kissingen
# Processing Record 45 of Set 8 | filadelfia
# Processing Record 46 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 8 | mahon
# Processing Record 48 of Set 8 | paamiut
# Processing Record 49 of Set 8 | yar-sale
# Processing Record 50 of Set 8 | aldan
# Processing Record 1 of Set 9 | touros
# Processing Record 2 of Set 9 | vuktyl
# Processing Record 3 of Set 9 | coahuayana
# Processing Record 4 of Set 9 | tabas
# Processing Record 5 of Set 9 | jatara
# Processing Record 6 of Set 9 | camiri
# Processing Record 7 of Set 9 | bor
# Processing Record 8 of Set 9 | villanueva
# Processing Record 9 of Set 9 | mercedes
# Processing Record 10 of Set 9 | aasiaat
# Processing Record 11 of Set 9 | victoria
# Processing Record 12 of Set 9 | san cristobal
# Processing Record 13 of Set 9 | opalenica
# Processing Record 14 of Set 9 | mihail kogalniceanu
# Processing Record 15 of Set 9 | urucara
# Processing Record 16 of Set 9 | vila
# Processing Record 17 of Set 9 | geraldton
# Processing Record 18 of Set 9 | banfora
# Processing Record 19 of Set 9 | alihe
# Processing Record 20 of Set 9 | klaksvik
# Processing Record 21 of Set 9 | bolonchen
# City not found. Skipping...
# Processing Record 22 of Set 9 | doha
# Processing Record 23 of Set 9 | sorland
# Processing Record 24 of Set 9 | tucurui
# Processing Record 25 of Set 9 | makakilo city
# Processing Record 26 of Set 9 | sao filipe
# Processing Record 27 of Set 9 | narsaq
# Processing Record 28 of Set 9 | ende
# Processing Record 29 of Set 9 | les cayes
# Processing Record 30 of Set 9 | vangaindrano
# Processing Record 31 of Set 9 | luanda
# Processing Record 32 of Set 9 | kununurra
# Processing Record 33 of Set 9 | kenora
# Processing Record 34 of Set 9 | aldergrove
# Processing Record 35 of Set 9 | mundi
# Processing Record 36 of Set 9 | penzance
# Processing Record 37 of Set 9 | mporokoso
# Processing Record 38 of Set 9 | najran
# Processing Record 39 of Set 9 | mackenzie
# Processing Record 40 of Set 9 | okha
# Processing Record 41 of Set 9 | tezu
# Processing Record 42 of Set 9 | develi
# Processing Record 43 of Set 9 | palmerston
# Processing Record 44 of Set 9 | koumac
# Processing Record 45 of Set 9 | porto novo
# Processing Record 46 of Set 9 | hilpoltstein
# Processing Record 47 of Set 9 | inhambane
# Processing Record 48 of Set 9 | ibra
# Processing Record 49 of Set 9 | inongo
# Processing Record 50 of Set 9 | tashla
# Processing Record 1 of Set 10 | salalah
# Processing Record 2 of Set 10 | union
# Processing Record 3 of Set 10 | fortuna
# Processing Record 4 of Set 10 | debre tabor
# Processing Record 5 of Set 10 | keetmanshoop
# Processing Record 6 of Set 10 | port macquarie
# Processing Record 7 of Set 10 | marsaxlokk
# Processing Record 8 of Set 10 | marawi
# Processing Record 9 of Set 10 | road town
# Processing Record 10 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 11 of Set 10 | roebourne
# Processing Record 12 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 13 of Set 10 | san andres
# Processing Record 14 of Set 10 | tocopilla
# Processing Record 15 of Set 10 | hudiksvall
# Processing Record 16 of Set 10 | three hills
# Processing Record 17 of Set 10 | guerrero negro
# Processing Record 18 of Set 10 | pella
# Processing Record 19 of Set 10 | sungaipenuh
# Processing Record 20 of Set 10 | hokitika
# Processing Record 21 of Set 10 | urengoy
# Processing Record 22 of Set 10 | saint-louis
# Processing Record 23 of Set 10 | grand gaube
# Processing Record 24 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 10 | rabak
# Processing Record 26 of Set 10 | newport
# Processing Record 27 of Set 10 | ceres
# Processing Record 28 of Set 10 | yershov
# Processing Record 29 of Set 10 | masuguru
# Processing Record 30 of Set 10 | andrews
# Processing Record 31 of Set 10 | reyes
# Processing Record 32 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 33 of Set 10 | butajira
# Processing Record 34 of Set 10 | pascagoula
# Processing Record 35 of Set 10 | jawhar
# Processing Record 36 of Set 10 | ishigaki
# Processing Record 37 of Set 10 | udachnyy
# Processing Record 38 of Set 10 | anchorage
# Processing Record 39 of Set 10 | melivoia
# Processing Record 40 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 41 of Set 10 | priargunsk
# Processing Record 42 of Set 10 | laranjeiras do sul
# Processing Record 43 of Set 10 | ipixuna
# Processing Record 44 of Set 10 | necochea
# Processing Record 45 of Set 10 | pozo colorado
# Processing Record 46 of Set 10 | kadhan
# Processing Record 47 of Set 10 | kaeo
# Processing Record 48 of Set 10 | morro bay
# Processing Record 49 of Set 10 | luderitz
# Processing Record 50 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 1 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 2 of Set 11 | mattawa
# Processing Record 3 of Set 11 | jinchengjiang
# City not found. Skipping...
# Processing Record 4 of Set 11 | grand-santi
# Processing Record 5 of Set 11 | kamaishi
# Processing Record 6 of Set 11 | tupik
# Processing Record 7 of Set 11 | mamallapuram
# Processing Record 8 of Set 11 | timra
# Processing Record 9 of Set 11 | bambanglipuro
# Processing Record 10 of Set 11 | sajkas
# Processing Record 11 of Set 11 | sibu
# Processing Record 12 of Set 11 | knittelfeld
# Processing Record 13 of Set 11 | walvis bay
# Processing Record 14 of Set 11 | ukiah
# Processing Record 15 of Set 11 | humaita
# Processing Record 16 of Set 11 | mana
# Processing Record 17 of Set 11 | uige
# Processing Record 18 of Set 11 | talaya
# Processing Record 19 of Set 11 | bugulma
# Processing Record 20 of Set 11 | nesbyen
# Processing Record 21 of Set 11 | bereznik
# Processing Record 22 of Set 11 | puerto escondido
# Processing Record 23 of Set 11 | milton
# Processing Record 24 of Set 11 | nome
# Processing Record 25 of Set 11 | pachperwa
# Processing Record 26 of Set 11 | manakara
# Processing Record 27 of Set 11 | baie-comeau
# Processing Record 28 of Set 11 | sauce
# Processing Record 29 of Set 11 | spornoye
# Processing Record 30 of Set 11 | fare
# Processing Record 31 of Set 11 | lagoa
# Processing Record 32 of Set 11 | maryville
# Processing Record 33 of Set 11 | klyuchi
# Processing Record 34 of Set 11 | parli
# Processing Record 35 of Set 11 | port lincoln
# Processing Record 36 of Set 11 | jeremie
# Processing Record 37 of Set 11 | yumen
# Processing Record 38 of Set 11 | puerto carreno
# Processing Record 39 of Set 11 | honiara
# Processing Record 40 of Set 11 | oranjemund
# Processing Record 41 of Set 11 | magalia
# Processing Record 42 of Set 11 | zabol
# Processing Record 43 of Set 11 | hambantota
# Processing Record 44 of Set 11 | iskateley
# Processing Record 45 of Set 11 | teguise
# Processing Record 46 of Set 11 | omsukchan
# Processing Record 47 of Set 11 | pangkalanbuun
# Processing Record 48 of Set 11 | tupancireta
# Processing Record 49 of Set 11 | tabuk
# Processing Record 50 of Set 11 | umm lajj
# Processing Record 1 of Set 12 | kavaratti
# Processing Record 2 of Set 12 | ust-ordynskiy
# Processing Record 3 of Set 12 | borgarnes
# Processing Record 4 of Set 12 | itarantim
# Processing Record 5 of Set 12 | clonakilty
# Processing Record 6 of Set 12 | tilichiki
# Processing Record 7 of Set 12 | viedma
# Processing Record 8 of Set 12 | chicama
# Processing Record 9 of Set 12 | wairoa
# Processing Record 10 of Set 12 | mantes-la-ville
# Processing Record 11 of Set 12 | greytown
# Processing Record 12 of Set 12 | katete
# Processing Record 13 of Set 12 | richards bay
# Processing Record 14 of Set 12 | laguna
# Processing Record 15 of Set 12 | cortez
# Processing Record 16 of Set 12 | dandong
# Processing Record 17 of Set 12 | rio grande
# Processing Record 18 of Set 12 | nha trang
# Processing Record 19 of Set 12 | nechi
# Processing Record 20 of Set 12 | concordia
# Processing Record 21 of Set 12 | bavly
# Processing Record 22 of Set 12 | marsh harbour
# Processing Record 23 of Set 12 | kaoma
# Processing Record 24 of Set 12 | zima
# Processing Record 25 of Set 12 | watertown
# Processing Record 26 of Set 12 | aborlan
# Processing Record 27 of Set 12 | si satchanalai
# Processing Record 28 of Set 12 | saint-georges
# Processing Record 29 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 12 | souillac
# Processing Record 31 of Set 12 | ramanuj ganj
# Processing Record 32 of Set 12 | mariental
# Processing Record 33 of Set 12 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 34 of Set 12 | mount gambier
# Processing Record 35 of Set 12 | sur
# Processing Record 36 of Set 12 | broome
# Processing Record 37 of Set 12 | russell
# Processing Record 38 of Set 12 | ulladulla
# Processing Record 39 of Set 12 | santa fe
# Processing Record 40 of Set 12 | edd
# Processing Record 41 of Set 12 | mikhaylovka
# Processing Record 42 of Set 12 | nalut
# Processing Record 43 of Set 12 | lipin bor
# Processing Record 44 of Set 12 | pemangkat
# Processing Record 45 of Set 12 | poum
# Processing Record 46 of Set 12 | sigayevo
# Processing Record 47 of Set 12 | gilgit
# Processing Record 48 of Set 12 | luau
# Processing Record 49 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 50 of Set 12 | taltal
# Processing Record 1 of Set 13 | anshun
# Processing Record 2 of Set 13 | matara
# Processing Record 3 of Set 13 | hay river
# Processing Record 4 of Set 13 | gazanjyk
# Processing Record 5 of Set 13 | srandakan
# Processing Record 6 of Set 13 | naryan-mar
# Processing Record 7 of Set 13 | port-gentil
# Processing Record 8 of Set 13 | quang ngai
# Processing Record 9 of Set 13 | korla
# Processing Record 10 of Set 13 | wanning
# Processing Record 11 of Set 13 | diego de almagro
# Processing Record 12 of Set 13 | mariestad
# Processing Record 13 of Set 13 | sebezh
# Processing Record 14 of Set 13 | vao
# Processing Record 15 of Set 13 | afua
# Processing Record 16 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 17 of Set 13 | kamenka
# Processing Record 18 of Set 13 | kijang
# Processing Record 19 of Set 13 | bajo baudo
# City not found. Skipping...
# Processing Record 20 of Set 13 | tibacuy
# Processing Record 21 of Set 13 | rawlins
# Processing Record 22 of Set 13 | nhulunbuy
# Processing Record 23 of Set 13 | bandhi
# Processing Record 24 of Set 13 | adrar
# Processing Record 25 of Set 13 | san carlos de bariloche
# Processing Record 26 of Set 13 | magistralnyy
# Processing Record 27 of Set 13 | waingapu
# Processing Record 28 of Set 13 | voh
# Processing Record 29 of Set 13 | kuusamo
# Processing Record 30 of Set 13 | dingle
# Processing Record 31 of Set 13 | juan lacaze
# Processing Record 32 of Set 13 | roald
# Processing Record 33 of Set 13 | arraias
# Processing Record 34 of Set 13 | jijiga
# Processing Record 35 of Set 13 | nelson bay
# Processing Record 36 of Set 13 | okhotsk
# Processing Record 37 of Set 13 | broken hill
# Processing Record 38 of Set 13 | tonota
# Processing Record 39 of Set 13 | nuevo progreso
# Processing Record 40 of Set 13 | loubomo
# Processing Record 41 of Set 13 | ust-ishim
# Processing Record 42 of Set 13 | domoni
# Processing Record 43 of Set 13 | kedrovyy
# Processing Record 44 of Set 13 | goderich
# Processing Record 45 of Set 13 | louis trichardt
# Processing Record 46 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 13 | sohag
# Processing Record 48 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 13 | igarka
# Processing Record 50 of Set 13 | alugan
# Processing Record 1 of Set 14 | salinopolis
# Processing Record 2 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 3 of Set 14 | awbari
# Processing Record 4 of Set 14 | yunjinghong
# City not found. Skipping...
# Processing Record 5 of Set 14 | aneby
# Processing Record 6 of Set 14 | canavieiras
# Processing Record 7 of Set 14 | puerto madryn
# Processing Record 8 of Set 14 | burhaniye
# Processing Record 9 of Set 14 | tres arroyos
# Processing Record 10 of Set 14 | kaili
# Processing Record 11 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 12 of Set 14 | aksarka
# Processing Record 13 of Set 14 | cururupu
# Processing Record 14 of Set 14 | horsham
# Processing Record 15 of Set 14 | komsomolskiy
# Processing Record 16 of Set 14 | floresta
# Processing Record 17 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 18 of Set 14 | stephanskirchen
# Processing Record 19 of Set 14 | palu
# Processing Record 20 of Set 14 | pimentel
# Processing Record 21 of Set 14 | vidim
# Processing Record 22 of Set 14 | port augusta
# Processing Record 23 of Set 14 | boguchany
# Processing Record 24 of Set 14 | gryazovets
# Processing Record 25 of Set 14 | dibulla
# Processing Record 26 of Set 14 | caravelas
# Processing Record 27 of Set 14 | stalskoye
# Processing Record 28 of Set 14 | acarau
# Processing Record 29 of Set 14 | yarmouth
# Processing Record 30 of Set 14 | mahajanga
# Processing Record 31 of Set 14 | santa cecilia
# Processing Record 32 of Set 14 | high prairie
# Processing Record 33 of Set 14 | verkhnevilyuysk
# Processing Record 34 of Set 14 | marsabit
# Processing Record 35 of Set 14 | dicabisagan
# Processing Record 36 of Set 14 | remiremont
# Processing Record 37 of Set 14 | bilibino
# Processing Record 38 of Set 14 | meulaboh
# Processing Record 39 of Set 14 | mbigou
# Processing Record 40 of Set 14 | bendigo
# Processing Record 41 of Set 14 | turbat
# Processing Record 42 of Set 14 | thinadhoo
# Processing Record 43 of Set 14 | kadykchan
# City not found. Skipping...
# Processing Record 44 of Set 14 | masindi
# Processing Record 45 of Set 14 | booue
# Processing Record 46 of Set 14 | huntingdon
# Processing Record 47 of Set 14 | we
# City not found. Skipping...
# Processing Record 48 of Set 14 | kenai
# Processing Record 49 of Set 14 | bafra
# Processing Record 50 of Set 14 | irbit
# Processing Record 1 of Set 15 | santa maria
# Processing Record 2 of Set 15 | manzanillo
# Processing Record 3 of Set 15 | moranbah
# Processing Record 4 of Set 15 | pochutla
# Processing Record 5 of Set 15 | ambon
# Processing Record 6 of Set 15 | guayaramerin
# Processing Record 7 of Set 15 | carutapera
# Processing Record 8 of Set 15 | dalby
# Processing Record 9 of Set 15 | dalgopol
# Processing Record 10 of Set 15 | skibbereen
# Processing Record 11 of Set 15 | rock sound
# Processing Record 12 of Set 15 | hobyo
# Processing Record 13 of Set 15 | manoharpur
# Processing Record 14 of Set 15 | jiayuguan
# Processing Record 15 of Set 15 | sesheke
# Processing Record 16 of Set 15 | mantua
# Processing Record 17 of Set 15 | boyolangu
# Processing Record 18 of Set 15 | charagua
# Processing Record 19 of Set 15 | ballitoville
# Processing Record 20 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 21 of Set 15 | monrovia
# Processing Record 22 of Set 15 | arawa
# Processing Record 23 of Set 15 | jinchang
# Processing Record 24 of Set 15 | camopi
# Processing Record 25 of Set 15 | hualmay
# Processing Record 26 of Set 15 | zakamensk
# Processing Record 27 of Set 15 | aswan
# Processing Record 28 of Set 15 | mnogovershinnyy
# Processing Record 29 of Set 15 | aleksandrov gay
# Processing Record 30 of Set 15 | toora-khem
# Processing Record 31 of Set 15 | ayr
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# check number of cities
len(city_data)
# Out:
# 676

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Isangel      VU -19.5500  169.2667     89.71        70          75
# 1         Iqaluit      CA  63.7506  -68.5145    -27.31        74           0
# 2        Ambilobe      MG -13.2000   49.0500     83.32        76          28
# 3        Acapulco      MX  16.8634  -99.8901     76.17        82           9
# 4  Krasnoznamensk      RU  55.5994   37.0386     35.69        93         100
# 5           Jumla      NP  29.2747   82.1838     50.58        29           0
# 6         Ushuaia      AR -54.8000  -68.3000     49.66        71          20
# 7           Kandi      BJ  11.1342    2.9386     73.17        17          12
# 8       Cape Town      ZA -33.9258   18.4232     70.12        70           0
# 9           Kapaa      US  22.0752 -159.3190     73.72        75          75
#
#    Wind Speed      Current Description
# 0        5.75            broken clouds
# 1        8.99                clear sky
# 2        1.19         scattered clouds
# 3        4.18                clear sky
# 4       11.18  light intensity drizzle
# 5        4.38                clear sky
# 6       19.57               few clouds
# 7        4.72               few clouds
# 8       16.11                clear sky
# 9       14.97            broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
